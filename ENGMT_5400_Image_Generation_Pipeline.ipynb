# %% [markdown]
# How to use this:
#
# *   Unzip the Zip file for Image_Generation_Pipeline, upload the folder to your google drive. It should be sitting somewhere "/content/drive/MyDrive/Image_Generation_Pipeline_code"
# *  Run this colab notebook in sequential, except the last code block, it is used for downloading the pipeline locally.

# %%
# Uninstall to avoid version conflicts (run first!)
# !pip uninstall -y gradio gradio_client huggingface_hub diffusers transformers

# Main package installation (pin major packages as local)
# !pip install torch==2.7.0 torchvision==0.22.0 torchaudio==2.7.0 --index-url https://download.pytorch.org/whl/cu118
# !pip install gradio==5.27.0
# !pip install gradio-image-annotation==0.2.6
# !pip install diffusers==0.33.1
# !pip install huggingface_hub==0.30.2
# !pip install transformers==4.51.3
# !pip install open_clip_torch==2.32.0
# !pip install pillow==11.0.0 tqdm==4.67.1 einops==0.8.1 safetensors==0.5.3 pandas==2.2.3
# !pip install openai==1.76.0
# !pip install xformers


# Clean up
import os
os.kill(os.getpid(), 9)  # Force Colab runtime restart for version consistency!
# Out:
# WARNING: Skipping gradio as it is not installed.
# WARNING: Skipping gradio_client as it is not installed.
# Found existing installation: huggingface-hub 0.30.2
# Uninstalling huggingface-hub-0.30.2:
#   Successfully uninstalled huggingface-hub-0.30.2
# Found existing installation: diffusers 0.33.1
# Uninstalling diffusers-0.33.1:
#   Successfully uninstalled diffusers-0.33.1
# Found existing installation: transformers 4.51.3
# Uninstalling transformers-4.51.3:
#   Successfully uninstalled transformers-4.51.3
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 23.2/23.2 MB 247.3 MB/s eta 0:00:01
# ERROR: Operation cancelled by user
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 32.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.9 MB/s eta 0:00:00
# ...

# %%
# install ip-adapter
# !pip install git+https://github.com/tencent-ailab/IP-Adapter.git

# 1. Install git-lfs (once per session)
# !apt-get install git-lfs

# 2. Clone the repo to /content (Colab local temp storage)
# !git clone https://huggingface.co/h94/IP-Adapter

# %%
# !python "/content/drive/MyDrive/Image_Generation_Pipeline_code/ui/interface_main.py"
# Out:
# 2025-04-29 00:10:11.908983: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745885411.931632   25851 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745885411.938352   25851 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://65fc50272e66c85dd5.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
#
# ...

# %%
import shutil
from google.colab import files

# Replace with your folder path
FOLDER_PATH = "/content/project/Image Generation Pipeline_code"

# Zip the folder (creates /content/your_folder.zip)
shutil.make_archive("/content/Image Generation Pipeline_code", 'zip', FOLDER_PATH)

# Download the zip file
files.download("/content/Image Generation Pipeline_code.zip")
